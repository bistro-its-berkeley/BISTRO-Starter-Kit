# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.cm import ScalarMappable
import seaborn as sns
sns.set()
# %matplotlib inline

# Adding the module to the path for future import
# Note that the following is idempotent when this notebook is run from "/examples"
import sys
import os
from os import path
from pathlib import Path
os.chdir('../utilities')
import visualization as viz
import plans_parser as parser

import tqdm
import math

# To parse .xml output files
from lxml import etree


# %load_ext autoreload
# %autoreload 2

# %%
COMPETITION = "competition"
SUBMISSION_INPUTS = "submission-inputs"
ITERS = "ITERS"
REFERENCE_DATA = "reference-data"
SCENARIO_NAME = "sioux_faux"
AGENCY = "sioux_faux_bus_lines"
CONFIG = "config"
EXAMPLES = "examples"

path_input = (Path.cwd().parent / "submission-inputs").absolute()

# ********** CHANGE SAMPLE_SIZE (string) *******************#
# 1k or 15k
SAMPLE_SIZE = '15k'

# ********** CHANGE iter_number (integer) *******************#
iter_number = 20
ITER_FOLDER = f"it.{iter_number}"

# PATHS TO BAU DATA 
# 1.ouput folder
path_output_folder_bau = (Path.cwd().parent / REFERENCE_DATA / SCENARIO_NAME / f"bau/warm-start/sioux_faux-{SAMPLE_SIZE}__warm-start").absolute()
path_output_folder_bau = viz.unzip_file(path_output_folder_bau)

# 2. Network and population files
path_network_file = Path.cwd().parent / REFERENCE_DATA /SCENARIO_NAME / CONFIG/ "physsim-network.xml"
path_population_file = Path.cwd().parent / REFERENCE_DATA /SCENARIO_NAME / CONFIG / f"{SAMPLE_SIZE}/population.xml.gz"

# ********** CHANGE PATH OUTPUT FOLDER (pathlib.Path object)*****************#
path_output_folder = Path.cwd().parent / EXAMPLES / "example_run_output_folder"

# %%
max_incentive = 50
max_income = 150000
max_age = 120
max_fare = 10
transit_scale_factor = 0.1

poi_types = ['work', 'secondary']
time_ranges = {'morning peak': range(7, 10), "evening peak": range(17, 20)}
max_time = 900
utm_zone = "14N"

# Importing agencies ids from agency.txt
agency_ids = pd.read_csv(Path.cwd().parent / REFERENCE_DATA / SCENARIO_NAME / AGENCY / "gtfs_data/agency.txt")
agency_ids = agency_ids["agency_id"].tolist()

# Importing route ids from `routes.txt`
route_df = pd.read_csv(Path.cwd().parent / REFERENCE_DATA / SCENARIO_NAME / AGENCY /"gtfs_data/routes.txt")
route_ids = route_df["route_id"].sort_values(ascending = True).tolist()

# Importing vehicle types and seating capacities from `availableVehicleTypes.csv` file
available_vehicle_types = pd.read_csv(Path.cwd().parent / REFERENCE_DATA / SCENARIO_NAME / AGENCY /"availableVehicleTypes.csv")

buses_list = available_vehicle_types["vehicleTypeId"][1:].tolist()
seating_capacities = available_vehicle_types[["vehicleTypeId", "seatingCapacity"]].set_index("vehicleTypeId", drop=True).T.to_dict("records")[0]

# Extracting Operational costs per bus type from the `vehicleCosts.csv` file
operational_costs = pd.read_csv(Path.cwd().parent / REFERENCE_DATA / SCENARIO_NAME / AGENCY / "vehicleCosts.csv")
operational_costs = operational_costs[["vehicleTypeId", "opAndMaintCost"]].set_index("vehicleTypeId", drop=True).T.to_dict("records")[0]

# Extracting route_id / trip_id correspondence from the `trips.csv` file
trips = pd.read_csv(Path.cwd().parent / REFERENCE_DATA / SCENARIO_NAME / AGENCY / "gtfs_data/trips.txt")
trip_to_route = trips[["trip_id", "route_id"]].set_index("trip_id", drop=True).T.to_dict('records')[0]

# Extracting bus fares from the submission input csv: "submission-inputs/MassTransitFares.csv"
bus_fares_df = pd.read_csv(path_output_folder_bau / COMPETITION / SUBMISSION_INPUTS / "MassTransitFares.csv")

#Extracting Fuel cost from the `beamFuelTypes.csv` file
fuel_costs = pd.read_csv(Path.cwd().parent / REFERENCE_DATA / SCENARIO_NAME / CONFIG / SAMPLE_SIZE / "beamFuelTypes.csv")
fuel_costs.loc[len(fuel_costs)] = ["food", 0]
fuel_costs = fuel_costs.set_index("fuelTypeId", drop=True).T.to_dict('records')[0]

# %%
# Importing all xml.gz files from the output folder of the run
events_path = path_output_folder_bau / "outputEvents.xml.gz"
output_plans_path = path_output_folder_bau / "outputPlans.xml.gz"
experienced_plans_path = path_output_folder_bau / ITERS / "it.100" / "100.experiencedPlans.xml.gz"
persons_path = path_output_folder_bau / "outputPersonAttributes.xml.gz"
households_path = path_output_folder_bau / "outputHouseholds.xml.gz"

# %%
# %%time
persons_attributes_df = parser.extract_person_dataframes(output_plans_path, 
                                                         persons_path, households_path, 
                                                         path_output_folder)
# Out:
# person_dataframe.csv generated
# CPU times: user 3.27 s, sys: 446 ms, total: 3.72 s
# Wall time: 3.72 s

# %%
# %%time
activities_df = parser.extract_activities_dataframes(experienced_plans_path, path_output_folder)
# Out:
# activities_dataframe.csv generated
# CPU times: user 912 ms, sys: 58.4 ms, total: 970 ms
# Wall time: 978 ms

# %%
# %%time
trips_df = parser.get_trips_output(experienced_plans_path)
# Out:
# CPU times: user 1.28 s, sys: 69.7 ms, total: 1.35 s
# Wall time: 1.37 s

# %%
trips_df.columns
# Out:
# Index(['PID', 'Trip_ID', 'Origin_Activity_ID', 'Destination_activity_ID',
#        'Trip_Purpose', 'Mode', 'Start_time', 'Duration_sec', 'Distance_m',
#        'Path_linkIds'],
#       dtype='object')

# %%
# %%time
bus_fares_df = parser.parse_bus_fare_input(bus_fares_df, route_ids)
# Out:
# CPU times: user 4.78 ms, sys: 159 µs, total: 4.94 ms
# Wall time: 5.33 ms

# %%
legs_df = parser.extract_legs_dataframes(events_path, trips_df, persons_attributes_df, bus_fares_df, trip_to_route, fuel_costs, path_output_folder)
# Out:
# Empty DataFrame
# Columns: [time, type, person, vehicle, driver, vehicleType, length, numPassengers, departureTime, arrivalTime, mode, links, fuelType, fuel]
# Index: []
# Empty DataFrame
# Columns: [time, type, person, vehicle, driver, vehicleType, length, numPassengers, departureTime, arrivalTime, mode, links, fuelType, fuel]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-194-4aeab5ab9c79> in <module>()
# ----> 1 legs_df = parser.extract_legs_dataframes(events_path, trips_df, persons_attributes_df, bus_fares_df, trip_to_route, fuel_costs, path_output_folder)
#
# ~/Documents/GitHub/Uber-Prize-Starter-Kit/utilities/plans_parser.py in extract_legs_dataframes(events_path, trips_df, person_df, bus_fares_df, trip_to_route, fuel_costs, output_folder_path)
#     896     all_events_df = extract_dataframe(str(events_path))
#     897
# --> 898     legs_df, path_traversal_df = get_legs_output(all_events_df, trips_df)
#     899     path_traversal_df_new = calc_fuel_costs(path_traversal_df, fuel_costs)
#     900     path_traversal_df_new.to_csv(str(output_folder_path) + '/path_traversals_dataframe.csv')
#
# ~/Documents/GitHub/Uber-Prize-Starter-Kit/utilities/plans_parser.py in get_legs_output(events_df, trips_df)
#     762     transit_legs_array = transit_trips_df.apply(
#     763         lambda row: parse_transit_trips(row, non_bus_path_traversal_events, bus_path_traversal_events, enter_veh_events),
# --> 764         axis=1)
#     765     for bit in transit_legs_array.tolist():
#     766         legs_array.extend(tid for tid in bit)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# ~/Documents/GitHub/Uber-Prize-Starter-Kit/utilities/plans_parser.py in <lambda>(row)
#     761     transit_trips_df = trips_df[(trips_df['Mode'] == 'drive_transit') | (trips_df['Mode'] == 'walk_transit')]
#     762     transit_legs_array = transit_trips_df.apply(
# --> 763         lambda row: parse_transit_trips(row, non_bus_path_traversal_events, bus_path_traversal_events, enter_veh_events),
#     764         axis=1)
#     765     for bit in transit_legs_array.tolist():
#
# ~/Documents/GitHub/Uber-Prize-Starter-Kit/utilities/plans_parser.py in parse_transit_trips(row, non_bus_path_traversal_events, bus_path_traversal_events, enter_veh_events)
#     199             veh_id = bus_entry['vehicle']
#     200             leg_start_time = int(bus_entry['time'])
# --> 201             leg_end_time = int(post_path_trav['departureTime'].values[0])
#     202             leg_duration = int(leg_end_time - bus_entry['time'])
#     203             # find the path traversals of the bus corresponding to the bus entry for this trip, occuring between the last prev_path_traversal and the first post_path_traversal
#
# IndexError: ('index 0 is out of bounds for axis 0 with size 0', 'occurred at index 16')

# %%
final_trips_df = parser.merge_legs_trips(legs_df, trips_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c2c3a61df970> in <module>()
# ----> 1 persons_attributes_df = parser.extract_person_dataframes(output_plans_data, persons_data, hhd_data, output_folder)
#
# NameError: name 'output_plans_data' is not defined

# %% [markdown]
# # Test.

# %%
from pathlib import Path
p = Path(r"/Users/vgolfi/Documents/GitHub/Uber-Prize-Starter-Kit_GITLAB/reference-data/sioux_faux/bau/warm-start/sioux_faux-15k__warm-start/ITERS/it.100/100.legHistogramWalk.png")

# %%
p.suffix
# Out:
# '.png'

# %% [markdown]
# # get_person_output_from_households_xml

# %%
households_xml = parser.open_xml(r"/Users/vgolfi/Documents/GitHub/Uber-Prize-Starter-Kit_GITLAB/reference-data/sioux_faux/bau/warm-start/sioux_faux-15k__warm-start/outputHouseholds.xml")
households_root = households_xml.getroot()
hhd_array = []

# %%
for child in households_root:
    print(child.tag, child.attrib)
    pass
# Out:
# {http://www.matsim.org/files/dtd}household {'id': '10600-2013000431434-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1200-
0'}
# {http://www.matsim.org/files/dtd}household {'id': '600-2012000207266-0'}
# {http://www.matsim.org/files/dtd}household {'id': '405-2013001192909-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1106-2016000364640-1'}
# {http://www.matsim.org/files/dtd}household {'id': '405-2016001433052-0'}
# {http://www.matsim.org/files/dtd}household {'id': '408-2015000136494-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10104-2015001391700-2'}
# {http://www.matsim.org/files/dtd}household {'id': '1801-2015001291004-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1801-2013000481572-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10104-2012000166281-1'}
# {http://www.matsim.org/files/dtd}household {'id': '900-2014000906088-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10104-2016000527491-1'}
# {http://www.matsim.org/files/dtd}household {'id': '10103-2014001087840-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10102-2013000262864-0'}
# {http://www.matsim.org/files/dtd}household {'id': '300-2014001198914-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10104-2012000190101-9'}
# {http://www.matsim.org/files/dtd}household {'id': '10401-2013000787397-0'}
# {http://www.matsim.org/files/dtd}household {'id': '202-2016001431295-0'}
# {http://www.matsim.org/files/dtd}household {'id': '407-2016001273891-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1107-2015000133808-0'}
# {http://www.matsim.org/files/dtd}household {'id': '202-2016001517438-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1803-2012001048206-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10405-2016001120110-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1700-2015000450240-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1803-2013000831682-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1902-2013000377800-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1500-2015000118896-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1001-2013000703874-0'}
# {http://www.matsim.org/files/dtd}household {'id': '700-2014001171812-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1105-2014000448294-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1001-2016000435003-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1108-2014001079600-0'}
# {http://www.matsim.org/files/dtd}household {'id': '406-2015001250896-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1002-2012000044870-0'}
# {http://www.matsim.org/files/dtd}household {'id': '500-2012000408893-0'}
# {http://www.matsim.org/files/dtd}household {'id': '401-2016000878091-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10600-2014000585174-2'}
# {http://www.matsim.org/files/dtd}household {'id': '1105-2013001420823-0'}
# {http://www.matsim.org/files/dtd}household {'id': '406-2012001097565-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1803-2014000564473-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1106-2015000475027-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1105-2015000107452-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10103-2012000408856-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1002-2012000164709-2'}
# {http://www.matsim.org/files/dtd}household {'id': '900-2012001048206-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1107-2013000380547-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1101-2012000855549-1'}
# {http://www.matsim.org/files/dtd}household {'id': '10600-2016000423611-1'}
# {http://www.matsim.org/files/dtd}household {'id': '401-2014000054409-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1803-2014001002756-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1002-2016000116811-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1801-2016001262844-1'}
# {http://www.matsim.org/files/dtd}household {'id': '405-2015000879933-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1700-2013000487483-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1902-2015000224295-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1106-2013000226280-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1600-2012000629695-0'}
# {http://www.matsim.org/files/dtd}household {'id': '100-2012000840641-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1804-2015000392807-2'}
# {http://www.matsim.org/files/dtd}household {'id': '10102-2012001350676-1'}
# {http://www.matsim.org/files/dtd}household {'id': '10102-2015000816977-3'}
# {http://www.matsim.org/files/dtd}household {'id': '1200-2014001139730-0'}
# {http://www.matsim.org/files/dtd}household {'id': '700-2014000775952-0'}
# {http://www.matsim.org/files/dtd}household {'id': '401-2013000744216-0'}
# {http://www.matsim.org/files/dtd}household {'id': '401-2014000532744-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1803-2013000242796-0'}
# {http://www.matsim.org/files/dtd}household {'id': '405-2014000125384-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10102-2014000266090-1'}
# {http://www.matsim.org/files/dtd}household {'id': '406-2012001111261-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10102-2012000015028-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1107-2015000459678-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1902-2013000107064-0'}
# {http://www.matsim.org/files/dtd}household {'id': '401-2015000788333-0'}
# {http://www.matsim.org/files/dtd}household {'id': '600-2015000367198-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1901-2014001174412-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10102-2013001420823-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1804-2013000898478-0'}
# {http://www.matsim.org/files/dtd}household {'id': '407-2015001390631-0'}
# {http://www.matsim.org/files/dtd}household {'id': '300-2015001504336-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1106-2013000921416-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1101-2014001100354-1'}
# {http://www.matsim.org/files/dtd}household {'id': '202-2013000153074-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10103-2013000509270-0'}
# {http://www.matsim.org/files/dtd}household {'id': '202-2015001496113-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1105-2013001470432-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10103-2014000113616-2'}
# {http://www.matsim.org/files/dtd}household {'id': '1803-2015000354278-0'}
# {http://www.matsim.org/files/dtd}household {'id': '406-2016000995092-0'}
# {http://www.matsim.org/files/dtd}household {'id': '401-2016000874667-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1106-2014000790922-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1106-2012001315564-2'}
# {http://www.matsim.org/files/dtd}household {'id': '1101-2014000295948-0'}
# {http://www.matsim.org/files/dtd}household {'id': '405-2014000292394-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1105-2015000278550-0'}
# {http://www.matsim.org/files/dtd}household {'id': '405-2012000269732-1'}
# {http://www.matsim.org/files/dtd}household {'id': '100-2014001093458-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1002-2015000606577-0'}
# {http://www.matsim.org/files/dtd}household {'id': '405-2014000053367-0'}
# {http://www.matsim.org/files/dtd}household {'id': '10102-2016000610766-1'}
# {http://www.matsim.org/files/dtd}household {'id': '1500-2016001227839-0'}
# {http://www.matsim.org/files/dtd}household {'id': '1803-2015000528933-0'}

# %%
child_1 = households_root.findall('{http://www.matsim.org/files/dtd}household')

# %%
child.findall('members')
# Out:
# []

# %%
child_1[0].find("{http://www.matsim.org/files/dtd}income").text
# Out:
# '\n\t\t\t\t20936.0\n\t\t'

# %%
households_root
# Out:
# <Element {http://www.matsim.org/files/dtd}households at 0x1a2325c5c8>
