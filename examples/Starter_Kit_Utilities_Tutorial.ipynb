# %% [markdown]
# # Uber Prize Starter Kit Python Utilities: Tutorial

# %% [markdown]
# To simplify interaction with the Docker-based simulation execution and evaluation, we've provided a set of Python utilities (located in the `/utilities` folder of the Starter-Kit repository).This notebook demonstrates how they may be used to accomplish the following tasks:
#
#  - Starting a simulation or several simulations
#  - Checking simulation completion
#  - Retrieving the simulation score in a convenient Pandas `DataFrame` format.
#  - Generating fake data
#
# *Note 1*: This notebook and its accompanying utilities are written in Python 3.5+. Please install the associated requirements using the provided `requirements.txt` in the root folder.
#
# *Note 2*: It is assumed that this notebook is started from the `/examples` folder.

# %%
# Adding the module to the path for future import
import sys
import os
import docker
from pathlib import Path
# Note that the following is idempotent when this notebook is run from "/examples"
os.chdir('../utilities')
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Running a simulation: the `competition_executor` module

# %% [markdown]
# A `CompetitionContainerExecutor` object may be used to start, stop, and gather information about containers running simulations and/or completed simulation scores and stats.

# %%
from competition_executor import CompetitionContainerExecutor

# Current round uses "sioux faux" scenario
SCENARIO_NAME = "sioux_faux"

# Evaluation is on 15k sample, but for now we will use the 1k sample for demo purposes.
SAMPLE_SIZE = "1k"

path_input = (Path(Path.cwd()).parent / "submission-inputs").absolute()
path_output = (Path(Path.cwd()).parent / "output").absolute()

my_executor = CompetitionContainerExecutor(input_root=path_input,
                                  output_root=path_output)

# Note: Instantiating a CompetitionContainerExecutor with path arguments is not strictly necessary. Each simulation
# can be run with its own set of input and/or output arguments. However, if you prefer to designate
# a single directory for inputs and/or a single directory for outputs, then, for convenience, 
# you may pass those arguments in here and avoid re-entering them for each simulation run.

# %% [markdown]
# Run the simulation using the `run_simulation` method. For example:

# %%
# Note: the `submission name` for each run must be unique. However, this cell is designed to be run repeatedly. 
# If a simulation is currently in progress, it will be stopped and removed.
try:
    my_submission = my_executor.client.containers.get('my_submission')
    print("WARNING: The executor found a simulation named '{0}' (container ID '{1}') from a previous run.\n\
    - Stopping simulation and removing the old container.\n \
    - Creating new container and restarting simulator.\n \
    \n \
    ~~~Please wait a moment~~~".format(my_submission.name, my_submission.short_id))
    my_submission.stop()
    my_submission.remove()
except docker.errors.NotFound:
    print("Creating new container and starting simulator.\n \
    ~~~Please wait a moment~~~\n")
    
my_executor.run_simulation('my_submission', num_iterations=1, num_cpus=2, sample_size=SAMPLE_SIZE)

# Note that a dictionary indicating which simulation names already exist can be accessed.
for key, value in my_executor.containers.items():
    
    print("\nSuccessfully created new container and currently executing a simulation run\n \
    - Name: '{0}'\n \
    - Container ID : '{1}'\n \
    \n \
    ~~~Scores will be available when this run completes.~~~\n".format(value.name, value.id))
# Out:
# WARNING: The executor found a simulation named 'my_submission' (container ID '68123c78aa') from a previous run.
#     - Stopping simulation and removing the old container.
#      - Creating new container and restarting simulator.
#
#      ~~~Please wait a moment~~~
#
# Successfully created new container and currently executing a simulation run
#      - Name: 'my_submission'
#      - Container ID : 'c182a895e6'
#
#      ~~~Scores will be available when this run completes.~~~

# %% [markdown]
# You may view the parameters of your simulation using the `output_simulation_parameters(simulation_name)` method on the executor.

# %%
my_executor.output_simulation_parameters('my_submission')
print("~~~This simulation's parameters cannot be changed until this run completes.~~~\n")
# Out:
# Simulation parameters
#          - Submission id: 'my_submission'
#          - Timestamp: '2019-02-16_06-25-22'
#          - Scenario Name: 'sioux_faux'
#          - Number of Iterations: '1'
#          - Sample Size: '1k'
#
# ~~~This simulation's parameters cannot be changed until this run completes.~~~

# %% [markdown]
# You may view (or save to file) the **debug logs** of your simulation using the `output_simulation_logs(simulation_name,file_name)` method on the executor.
#
# To follow simulation progress, the following cell may be run repeatedly.

# %%
logs = my_executor.output_simulation_logs('my_submission')

# NOTE: While it may take a while to finish, as long as your execution environment meets 
# the minimum hardware requirements the  simulation is (most likely) not stuck! 

# However, if you notice that the logs do not change for 
# over 5 minutes, there is likely an error somewhere and you should stop the simulation (see below). 
# In this case, we would greatly appreciate it if you filed a bug report (issue) 
# together with your hardware environment (number of cpus, RAM, etc.) and a copy of the output 
# logs (zipped, preferably).
# Out:
# Dependency Service(s) Init Complete
# 7:C 16 Feb 06:25:19.869 # Warning: no config file specified, using the default config. In order to specify a config file use redis-server /path/to/redis.conf
#                 _._
#            _.-``__ ''-._
#       _.-``    `.  `_.  ''-._           Redis 3.2.6 (00000000/0) 64 bit
#   .-`` .-```.  ```\/    _.,_ ''-._
#  (    '      ,       .-`  | `,    )     Running in standalone mode
#  |`-._`-...-` __...-.``-._|'` _.-'|     Port: 6379
#  |    `-._   `._    /     _.-'    |     PID: 7
#   `-._    `-._  `-./  _.-'    _.-'
#  |`-._`-._    `-.__.-'    _.-'_.-'|
#  |    `-._`-._        _.-'_.-'    |           http://redis.io
#   `-._    `-._`-.__.-'_.-'    _.-'
#  |`-._`-._    `-.__.-'    _.-'_.-'|
#  |    `-._`-._        _.-'_.-'    |
#   `-._    `-._`-.__.-'_.-'    _.-'
#       `-._    `-.__.-'    _.-'
#           `-._        _.-'
#               `-.__.-'
#
# 7:M 16 Feb 06:25:19.870 # WARNING: The TCP backlog setting of 511 cannot be enforced because /proc/sys/net/core/somaxconn is set to the lower value of 128.
# 7:M 16 Feb 06:25:19.870 # Server started, Redis version 3.2.6
# 7:M 16 Feb 06:25:19.870 # WARNING you have Transparent Huge Pages (THP) support enabled in your kernel. This will create latency and memory usage issues with Redis. To fix this issue run the command 'echo never > /sys/kernel/mm/transparent_hugepage/enabled' as root, and add it to your /etc/rc.local in order to retain the setting after a reboot. Redis must be restarted after THP is disabled.
# 7:M 16 Feb 06:25:19.870 * The server is now ready to accept connections on port 6379
# 06:25:21.434 DEBUG beam.utils.BeamConfigUtils$ - Loading beam config from fixed-data/sioux_faux/sioux_faux-1k.conf.
# 06:25:22.831 DEBUG b.sim.config.MatSimBeamConfigBuilder - Couldn't instantiate MatsimParameters  'org.matsim.core.config.groups.PlanCalcScoreConfigGroup.ModeParams'. It doesn't have default public constructor.Falling back to setAccessible(). Cause : Class beam.sim.config.MatSimBeamConfigBuilder$$anonfun$1 can not access a member of class org.matsim.core.config.groups.PlanCalcScoreConfigGroup$ModeParams with modifiers ""
# 06:25:22.836 DEBUG b.sim.config.MatSimBeamConfigBuilder - Couldn't instantiate MatsimParameters  'org.matsim.run.OldToNewPlanCalcScoreConfigGroup.ModeParams'. It doesn't have default public constructor.Falling back to setAccessible(). Cause : Class beam.sim.config.MatSimBeamConfigBuilder$$anonfun$1 can not access a member of class org.matsim.run.OldToNewPlanCalcScoreConfigGroup$ModeParams with modifiers ""
# 06:25:22.930 DEBUG beam.utils.FileUtils$ - Beam output directory is: /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22
# 06:25:22.967 INFO  beam.competition.run.RunCompetition$ - Starting beam on branch master at commit HEAD.
# 06:25:22.994 INFO  beam.competition.run.RunCompetition$ - Config [sioux_faux-1k] copied to /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/beam.conf.
# 06:25:23.022 INFO  b.r.r.FrequencyAdjustingNetworkCoordinator - Initializing router by reading network from: /fixed-data/sioux_faux/r5/network.dat
# 06:25:25.738 INFO  hsqldb.db.HSQLDB4AD417742A.ENGINE - dataFileCache open start
# 06:25:26.685 INFO  beam.sim.BeamWarmStart - Population successfully warm started from /tmp/sioux_faux-1k__warm-start/ITERS/it.100/100.plans.xml.gz
# 06:25:30.170 INFO  beam.utils.NetworkHelperImpl - Build linkId2LinkWithIndex with size: 5918 of type class java.util.HashMap
# 06:25:30.174 INFO  beam.utils.NetworkHelperImpl - Build index2LinkId with size: 5918
# 06:25:30.174 INFO  beam.utils.NetworkHelperImpl - NetworkHelperImpl initialized in 69 ms
# 06:25:31.638 INFO  b.sim.LoggingParallelEventsManager - Created ParallelEventsManagerImpl with hashcode: 407254816
# 06:25:33.265 INFO  beam.router.osm.TollCalculator - tollsByLinkId size: 0
# 06:25:33.266 INFO  beam.router.osm.TollCalculator - tollsByWayId size: 0
# 06:25:33.337 DEBUG beam.utils.FileUtils$ - Beam output directory is: /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22
# 06:25:35.772 INFO  b.s.p.DefaultPopulationAdjustment - Modes' Availability:
# 06:25:35.791 INFO  b.s.p.DefaultPopulationAdjustment - (walk_transit,996)
# 06:25:35.791 INFO  b.s.p.DefaultPopulationAdjustment - (ride_hail_transit,996)
# 06:25:35.792 INFO  b.s.p.DefaultPopulationAdjustment - (ride_hail,996)
# 06:25:35.792 INFO  b.s.p.DefaultPopulationAdjustment - (walk,996)
# 06:25:35.793 INFO  b.s.p.DefaultPopulationAdjustment - (transit,996)
# 06:25:35.793 INFO  b.s.p.DefaultPopulationAdjustment - (car,741)
# 06:25:35.793 INFO  b.s.p.DefaultPopulationAdjustment - (drive_transit,741)
# 06:25:35.793 INFO  b.s.p.DefaultPopulationAdjustment - (bike,996)
# 06:25:36.130 DEBUG beam.sim.metrics.MetricsPrinter - Printer not subscribed.
# 06:25:36.131 DEBUG beam.sim.metrics.MetricsPrinter - Printer not subscribed.
# [INFO] [02/16/2019 06:25:36.182] [ClusterSystem-akka.actor.default-dispatcher-5] [akka://ClusterSystem/user/router] BeamRouter: akka://ClusterSystem/user/router
# [INFO] [02/16/2019 06:25:36.196] [ClusterSystem-akka.actor.default-dispatcher-4] [akka://ClusterSystem/user/router/router-worker] R5RoutingWorker_v2[457927210] `akka://ClusterSystem/user/router/router-worker` is ready
# [INFO] [02/16/2019 06:25:36.196] [ClusterSystem-akka.actor.default-dispatcher-4] [akka://ClusterSystem/user/router/router-worker] Num of available processors: 4. Will use: 2
# [INFO] [02/16/2019 06:25:36.230] [ClusterSystem-akka.actor.default-dispatcher-4] [akka://ClusterSystem/user/router/router-worker] linkIdMap is built in 34 ms
# 06:25:37.154 INFO  beam.sim.BeamMobsim - Starting Iteration
# 06:25:37.155 INFO  beam.sim.BeamMobsim - Preparing new Iteration (Start)
# 06:25:37.613 INFO  beam.sim.BeamMobsim - run.start (after GC): 0.1(GB)
# 06:25:37.622 INFO  b.sim.LoggingParallelEventsManager - Running dedicated blocking handler...
# 06:25:37.997 WARN  beam.utils.StuckFinder - There is no configuration for 'class beam.agentsim.agents.ridehail.RideHailAgent$StartShiftTrigger'
# 06:25:37.997 WARN  beam.utils.StuckFinder - There is no configuration for 'class beam.agentsim.agents.ridehail.RideHailResponseTrigger'
# 06:25:37.997 WARN  beam.utils.StuckFinder - There is no configuration for 'class beam.agentsim.agents.ridehail.RideHailAgent$EndShiftTrigger'
# 06:25:38.003 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.PersonAgent$ActivityStartTrigger => 20000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.PersonAgent$ActivityEndTrigger => 60000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.PersonAgent$PersonDepartureTrigger => 20000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.modalbehaviors.DrivesVehicle$StartLegTrigger => 18000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.modalbehaviors.DrivesVehicle$EndLegTrigger => 60000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.modalbehaviors.DrivesVehicle$AlightVehicleTrigger => 21000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.modalbehaviors.DrivesVehicle$BoardVehicleTrigger => 21000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.modalbehaviors.DrivesVehicle$StartRefuelTrigger => 21000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.modalbehaviors.DrivesVehicle$EndRefuelTrigger => 21000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.InitializeTrigger => 20000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.ridehail.RideHailManager$BufferedRideHailRequestsTrigger => 20000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.agents.ridehail.RideHailManager$RideHailRepositioningTrigger => 40000 ms
# 06:25:38.004 INFO  beam.utils.StuckFinder - class beam.agentsim.scheduler.BeamAgentScheduler$KillTrigger => 30000 ms
# [INFO] [02/16/2019 06:25:39.239] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/population] Initialized 412 households
# [INFO] [02/16/2019 06:25:40.438] [ClusterSystem-akka.actor.default-dispatcher-3] [akka://ClusterSystem/user/BeamMobsim.iteration/RideHailManager] Initialized 100 ride hailing agents
# 06:25:40.619 DEBUG beam.router.TransitInitializer - [1] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.621 DEBUG beam.router.TransitInitializer - [2] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.621 DEBUG beam.router.TransitInitializer - [4] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.621 DEBUG beam.router.TransitInitializer - [8] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.622 DEBUG beam.router.TransitInitializer - [16] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.623 DEBUG beam.router.TransitInitializer - [32] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.623 DEBUG beam.router.TransitInitializer - [64] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.625 DEBUG beam.router.TransitInitializer - [128] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# 06:25:40.629 INFO  beam.router.TransitInitializer - [1] Initialized transit trips in 1343 ms. Keys: 255, Values: 255
# 06:25:40.630 DEBUG beam.router.TransitInitializer - [256] no specific vehicleType available for mode and transit agency pair 'BUS-217', using default vehicleType instead
# [INFO] [02/16/2019 06:25:40.749] [ClusterSystem-akka.actor.default-dispatcher-4] [akka://ClusterSystem/user/BeamMobsim.iteration] Transit schedule has been initialized
# 06:25:41.214 DEBUG beam.router.LinkTravelTimeContainer - Stats fileName -> /tmp/sioux_faux-1k__warm-start/ITERS/it.100/100.linkstats.csv.gz is being loaded
# 06:25:42.004 INFO  beam.router.LinkTravelTimeContainer - LinkTravelTimeMap is initialized in 790 ms
# [INFO] [02/16/2019 06:25:42.005] [ClusterSystem-akka.actor.default-dispatcher-11] [akka://ClusterSystem/user/router/router-worker] R5RoutingWorker_v2[457927210], Path: `akka://ClusterSystem/user/router/router-worker` UpdateTravelTimeLocal. Set new travel time
# 06:25:42.030 INFO  b.utils.TravelTimeCalculatorHelper - GetLinkIdToTravelTimeArray for 5918 links with maxHour = 30 executed in 25 ms
# 06:25:42.031 INFO  beam.sim.BeamWarmStart - Travel times successfully warm started from /tmp/sioux_faux-1k__warm-start/ITERS/it.100/100.linkstats.csv.gz.
# [INFO] [02/16/2019 06:25:42.032] [ClusterSystem-akka.actor.default-dispatcher-4] [akka://ClusterSystem/user/BeamMobsim.iteration] Running BEAM Mobsim
# [INFO] [02/16/2019 06:25:42.032] [ClusterSystem-akka.actor.default-dispatcher-4] [akka://ClusterSystem/user/BeamMobsim.iteration] Preparing new Iteration (End)
# [INFO] [02/16/2019 06:25:42.032] [ClusterSystem-akka.actor.default-dispatcher-4] [akka://ClusterSystem/user/BeamMobsim.iteration] Starting Agentsim
# [INFO] [02/16/2019 06:25:42.033] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] starting scheduler at iteration 0
# [INFO] [02/16/2019 06:25:43.143] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 0.5 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.144] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 1.0 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.144] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 1.5 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.144] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 2.0 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.144] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 2.5 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.144] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 3.0 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.144] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 3.5 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.144] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 4.0 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.146] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 4.5 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.147] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 5.0 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.283] [ClusterSystem-akka.actor.default-dispatcher-12] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 5.5 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.412] [ClusterSystem-akka.actor.default-dispatcher-5] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 6.0 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:43.584] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 6.5 completed. 0.1(GB)
# [INFO] [02/16/2019 06:25:43.726] [ClusterSystem-akka.actor.default-dispatcher-11] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 7.0 completed. 0.1(GB)
# 06:25:43.959 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.960 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.960 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.961 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.961 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.961 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.961 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.973 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.976 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# 06:25:43.977 WARN  beam.router.LinkTravelTimeContainer - Got 30 as index for traveTimePerHour with max size 30. Something might be wrong!
# [INFO] [02/16/2019 06:25:44.543] [ClusterSystem-akka.actor.default-dispatcher-5] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 7.5 completed. 0.2(GB)
# [INFO] [02/16/2019 06:25:45.434] [ClusterSystem-akka.actor.default-dispatcher-7] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 8.0 completed. 0.3(GB)
# [INFO] [02/16/2019 06:25:46.923] [ClusterSystem-akka.actor.default-dispatcher-9] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] Hour 8.5 completed. 0.2(GB)
# [INFO] [02/16/2019 06:25
[ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration] Ending Agentsim
# [INFO] [02/16/2019 06:25:59.583] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration] Processing Agentsim Events (Start)
# [INFO] [02/16/2019 06:25:59.594] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/BeamMobsim.iteration/scheduler] aroundPostStop. Stopping all scheduled tasks...
# 06:25:59.614 INFO  beam.sim.BeamMobsim - Agentsim finished.
# 06:25:59.614 INFO  b.sim.LoggingParallelEventsManager - Set `isFinished` to true
# 06:25:59.616 INFO  b.sim.LoggingParallelEventsManager - Starting to wait dedicatedHandler future to finish...
# 06:25:59.629 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1600-2012000963809-319634 -> 448.0 -> [x=684157.6435919636][y=4821320.578384039]
# 06:25:59.754 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1106-2014000520011-172643 -> 402.0 -> [x=678490.5077860993][y=4822517.232638089]
# 06:26:00.583 INFO  b.sim.LoggingParallelEventsManager - Stopped dedicated handler(handleBlocking). Took 0 ms to process after stop
# 06:26:00.584 INFO  b.sim.LoggingParallelEventsManager - dedicatedHandler future finished.
# 06:26:00.596 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1101-2013000153074-032864 -> 450.0 -> [x=679371.9172886088][y=4820836.011546107]
# 06:26:00.801 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10102-2016001438850-0155549 -> 471.0 -> [x=681847.2530149805][y=4819531.18555451]
# 06:26:00.906 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1106-2014000520011-172600 -> 402.0 -> [x=678876.9028790734][y=4822781.3247594675]
# 06:26:00.936 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10102-2015001024517-0114513 -> 476.0 -> [x=680189.9116460214][y=4818918.320753253]
# 06:26:00.988 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1002-2016001487612-0157008 -> 412.0 -> [x=679363.6005500797][y=4822195.012631382]
# 06:26:01.000 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10102-2015001491257-0123631 -> 476.0 -> [x=680606.1676142969][y=4819207.020548305]
# 06:26:01.043 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1105-2016000166982-0128671 -> 474.0 -> [x=678568.1571674019][y=4819721.359620178]
# 06:26:01.045 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1106-2013001265598-456837 -> 422.0 -> [x=678717.3496826389][y=4821971.878901087]
# 06:26:01.073 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10103-2016000930780-0146580 -> 474.0 -> [x=678697.0447267998][y=4819558.76129083]
# 06:26:01.094 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10104-2013001059260-152815 -> 488.0 -> [x=683429.3561918876][y=4818874.575095503]
# 06:26:01.139 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1101-2015000364742-198025 -> 459.0 -> [x=681775.3758075807][y=4820289.644870397]
# 06:26:01.189 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1200-2014001122037-085080 -> 459.0 -> [x=681730.0849105217][y=4820447.078507527]
# 06:26:01.191 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1107-2016000905283-0146109 -> 422.0 -> [x=678501.667084426][y=4822145.305369778]
# 06:26:01.224 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-900-2015000102574-093027 -> 347.0 -> [x=680848.07052829][y=4824401.800501575]
# 06:26:01.274 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1500-2016001216686-0151321 -> 461.0 -> [x=683372.4967649756][y=4820494.125514957]
# 06:26:01.293 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-100-2012000559396-011108 -> 291.0 -> [x=683984.1269827296][y=4827272.936366442]
# 06:26:01.301 INFO  b.sim.LoggingParallelEventsManager - finishProcessing executed in 1687 ms
# 06:26:01.301 DEBUG b.sim.LoggingParallelEventsManager - Overall processed events: 244589
# 06:26:01.301 INFO  beam.sim.BeamMobsim - Events drained.
# 06:26:01.301 INFO  beam.sim.BeamMobsim - Processing Agentsim Events (End)
# 06:26:05.294 INFO  beam.sim.BeamSim - notifyIterationEnds.start (after GC): 0.1(GB)
# 06:26:05.368 INFO  b.p.j.AgentSimToPhysSimPlanConverter - JDEQSim Start
# 06:26:05.383 INFO  b.p.j.AgentSimToPhysSimPlanConverter - Memory Use Before JDEQSim (after GC): 0.2(GB)
# 06:26:05.901 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 5 completed. 0.1(GB)
# 06:26:06.329 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 6 completed. 0.1(GB)
# 06:26:06.345 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 7 completed. 0.1(GB)
# 06:26:06.688 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 8 completed. 0.1(GB)
# 06:26:07.018 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 9 completed. 0.1(GB)
# 06:26:07.389 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 10 completed. 0.1(GB)
# 06:26:07.451 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 11 completed. 0.2(GB)
# 06:26:07.707 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 12 completed. 0.1(GB)
# 06:26:08.033 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 13 completed. 0.1(GB)
# 06:26:08.194 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 14 completed. 0.2(GB)
# 06:26:08.238 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 15 completed. 0.2(GB)
# 06:26:08.685 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 16 completed. 0.1(GB)
# 06:26:09.185 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 17 completed. 0.1(GB)
# 06:26:09.635 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 18 completed. 0.1(GB)
# 06:26:09.734 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 19 completed. 0.2(GB)
# 06:26:09.794 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 20 completed. 0.2(GB)
# 06:26:10.202 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 21 completed. 0.2(GB)
# 06:26:10.686 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 22 completed. 0.2(GB)
# 06:26:10.966 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 23 completed. 0.2(GB)
# 06:26:11.019 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 24 completed. 0.2(GB)
# 06:26:11.262 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 25 completed. 0.1(GB)
# 06:26:11.506 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 26 completed. 0.2(GB)
# 06:26:11.858 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 27 completed. 0.2(GB)
# 06:26:11.871 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 28 completed. 0.2(GB)
# 06:26:11.888 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 29 completed. 0.2(GB)
# 06:26:11.903 INFO  b.p.j.AgentSimToPhysSimPlanConverter - Memory Use After JDEQSim (after GC): 0.2(GB)
# 06:26:11.910 INFO  b.p.j.AgentSimToPhysSimPlanConverter - JDEQSim End
# 06:26:12.005 INFO  b.utils.TravelTimeCalculatorHelper - GetLinkIdToTravelTimeArray for 5918 links with maxHour = 30 executed in 93 ms
# [INFO] [02/16/2019 06:26:12.006] [ClusterSystem-akka.actor.default-dispatcher-2] [akka://ClusterSystem/user/router/router-worker] R5RoutingWorker_v2[457927210], Path: `akka://ClusterSystem/user/router/router-worker` UpdateTravelTimeLocal. Set new travel time
# 06:26:12.127 INFO  b.p.j.AgentSimToPhysSimPlanConverter - PhysSim for iteration 0 took 6818 ms
# 06:26:15.275 INFO  b.a.p.GraphsStatsAgentSimEventsListener - modesAbsoluteError: -0.30051148851148834
# 06:26:15.279 INFO  b.a.p.GraphsStatsAgentSimEventsListener - modesRMSPError: -1.6788756700408056
# 06:26:19.794 INFO  b.a.a.r.RideHailIterationsStatsCollector - 62 rideHail vehicles (out of 100) were never moved and 0 vehicles were moved without a passenger, during whole day.
# 06:26:19.795 INFO  b.a.a.r.RideHailIterationsStatsCollector - Ride hail vehicles with no passengers:
follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.0/0.legHistogram.txt
# 06:26:20.346 INFO  beam.sim.BeamSim - Renaming file - 0.legHistogram_all.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.0/0.legHistogramAll.png
# 06:26:20.351 INFO  beam.sim.BeamSim - Renaming file - 0.legHistogram_car.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.0/0.legHistogramCar.png
# 06:26:20.355 INFO  beam.sim.BeamSim - Renaming file - 0.legHistogram_drive_transit.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.0/0.legHistogramDriveTransit.png
# 06:26:20.359 INFO  beam.sim.BeamSim - Renaming file - 0.legHistogram_ride_hail.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.0/0.legHistogramRideHail.png
# 06:26:20.363 INFO  beam.sim.BeamSim - Renaming file - 0.legHistogram_walk.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.0/0.legHistogramWalk.png
# 06:26:20.367 INFO  beam.sim.BeamSim - Renaming file - 0.legHistogram_walk_transit.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.0/0.legHistogramWalkTransit.png
# 06:26:20.371 INFO  beam.sim.BeamSim - Ending Iteration
# 06:26:21.253 DEBUG beam.replanning.BeamTimeMutator - Before Replanning BeamTimeMutator: Person-100-2012000325210-06178 - 4
# 06:26:21.258 DEBUG beam.replanning.BeamTimeMutator - After Replanning BeamTimeMutator: Person-100-2012000325210-06178 - 5
# 06:26:21.259 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2012000325210-06216 - 4
# 06:26:21.260 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2012000325210-06216 - 4
# 06:26:21.261 DEBUG beam.replanning.ClearModes - Before Replanning ClearModes: Person-100-2012000559396-010896 - 4
# 06:26:21.262 DEBUG beam.replanning.ClearModes - After Replanning ClearModes: Person-100-2012000559396-010896 - 5
# 06:26:21.263 DEBUG beam.replanning.ClearRoutes - Before Replanning ClearRoutes: Person-100-2012000559396-010949 - 4
# 06:26:21.264 DEBUG beam.replanning.ClearRoutes - After Replanning ClearRoutes: Person-100-2012000559396-010949 - 5
# 06:26:21.264 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2012000559396-011002 - 4
# 06:26:21.264 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2012000559396-011002 - 4
# 06:26:21.264 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2012000559396-011055 - 4
# 06:26:21.265 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2012000559396-011055 - 4
# 06:26:21.265 DEBUG beam.replanning.ClearRoutes - Before Replanning ClearRoutes: Person-100-2012000559396-011108 - 4
# 06:26:21.265 DEBUG beam.replanning.ClearRoutes - After Replanning ClearRoutes: Person-100-2012000559396-011108 - 5
# 06:26:21.265 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2012000559396-011161 - 4
# 06:26:21.265 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2012000559396-011161 - 4
# 06:26:21.266 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2012000559396-011214 - 4
# 06:26:21.266 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2012000559396-011214 - 4
# 06:26:21.266 DEBUG beam.replanning.ClearRoutes - Before Replanning ClearRoutes: Person-100-2012000559396-011267 - 4
# 06:26:21.266 DEBUG beam.replanning.ClearRoutes - After Replanning ClearRoutes: Person-100-2012000559396-011267 - 5
# 06:26:21.266 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2012000559396-011320 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2012000559396-011320 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2014000728802-076263 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2014000728802-076263 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2014001217922-087811 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2014001217922-087811 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2014001404766-090700 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2014001404766-090700 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2014001404766-090737 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2014001404766-090737 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2014001404766-090774 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2014001404766-090774 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2015000189392-194673 - 4
# 06:26:21.267 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2015000189392-194673 - 4
# 06:26:21.267 DEBUG beam.replanning.ClearRoutes - Before Replanning ClearRoutes: Person-100-2015000189392-194755 - 4
# 06:26:21.268 DEBUG beam.replanning.ClearRoutes - After Replanning ClearRoutes: Person-100-2015000189392-194755 - 5
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2015000189392-194837 - 4
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2015000189392-194837 - 4
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2015000392807-198606 - 4
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2015000392807-198606 - 4
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2015001265529-0119585 - 4
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2015001265529-0119585 - 4
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-100-2016000749016-0142516 - 4
# 06:26:21.268 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-100-2016000749016-0142516 - 4
# 06:26:21.268 DEBUG beam.replanning.ClearModes - Before Replanning ClearModes: Person-1001-2012000826404-016421 - 4
# 06:26:21.269 DEBUG beam.replanning.ClearModes - After Replanning ClearModes: Person-1001-2012000826404-016421 - 5
# 06:26:21.269 DEBUG beam.replanning.ClearRoutes - Before Replanning ClearRoutes: Person-1001-2012000826404-016464 - 4
# 06:26:21.269 DEBUG beam.replanning.ClearRoutes - After Replanning ClearRoutes: Person-1001-2012000826404-016464 - 5
# 06:26:21.269 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-1001-2012001404956-028057 - 4
# 06:26:21.269 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-1001-2012001404956-028057 - 4
# 06:26:21.269 DEBUG beam.replanning.ClearModes - Before Replanning ClearModes: Person-1001-2012001404956-028085 - 4
# 06:26:21.269 DEBUG beam.replanning.ClearModes - After Replanning ClearModes: Person-1001-2012001404956-028085 - 5
# 06:26:21.269 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-1001-2014000292394-068075 - 4
# 06:26:21.269 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-1001-2014000292394-068075 - 4
# 06:26:21.269 DEBUG beam.replanning.ClearModes - Before Replanning ClearModes: Person-1001-2014000292394-068222 - 4
# 06:26:21.270 DEBUG beam.replanning.ClearModes - After Replanning ClearModes: Person-1001-2014000292394-068222 - 5
# 06:26:21.270 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-1001-2014000292394-068369 - 4
# 06:26:21.270 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-1001-2014000292394-068369 - 4
# 06:26:21.270 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-1001-2014001213505-087573 - 4
# 06:26:21.270 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-1001-2014001213505-087573 - 4
# 06:26:21.270 DEBUG beam.replanning.BeamExpBeta - Before ExpBetaPlanSelector: Person-1001-2014001213505-087617 - 4
# 06:26:21.270 DEBUG beam.replanning.BeamExpBeta - After ExpBetaPlanSelector: Person-1001-2014001213505-087617 - 4
# 06:26:21.270 DEBUG beam.replanning.BeamTimeMutator - Before Replanning BeamTimeMutator: Person-1001-2014001213505-087661 - 4
# ...
# 06:26:35.154 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1107-2016000905283-0146109 -> 422.0 -> [x=678506.6257234253][y=4821981.492456972]
# 06:26:35.174 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10103-2014000874813-079083 -> 474.0 -> [x=678697.0447267998][y=4819558.76129083]
# 06:26:35.214 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1002-2016001487612-0157008 -> 412.0 -> [x=679363.6005500797][y=4822195.012631382]
# 06:26:35.220 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-300-2016000833173-0144638 -> 306.0 -> [x=686292.5158219023][y=4826038.875885458]
# 06:26:35.223 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10405-2015000087715-092868 -> 267.0 -> [x=679382.6709286888][y=4827674.638063433]
# 06:26:35.225 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10102-2015001491257-0123631 -> 476.0 -> [x=680606.1676142969][y=4819207.020548305]
# 06:26:35.263 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10102-2015001024517-0114513 -> 476.0 -> [x=680189.9116460214][y=4818918.320753253]
# 06:26:35.269 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1106-2013001265598-456837 -> 422.0 -> [x=678717.3496826389][y=4821971.878901087]
# 06:26:35.274 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-10104-2013001059260-152815 -> 488.0 -> [x=683429.3561918876][y=4818874.575095503]
# 06:26:35.294 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1101-2015000364742-198025 -> 459.0 -> [x=681775.3758075807][y=4820289.644870397]
# 06:26:35.327 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1200-2014001122037-085080 -> 459.0 -> [x=681730.0849105217][y=4820447.078507527]
# 06:26:35.337 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1500-2016001216686-0151321 -> 461.0 -> [x=683171.3418372832][y=4820489.185916988]
# 06:26:35.381 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-1500-2014001225955-087959 -> 470.0 -> [x=683079.2203149152][y=4820282.702474024]
# 06:26:35.382 DEBUG b.a.a.r.RideHailIterationsStatsCollector - rideHailVehicle-100-2012000559396-011108 -> 291.0 -> [x=683984.1269827296][y=4827272.936366442]
# 06:26:35.386 INFO  b.sim.LoggingParallelEventsManager - finishProcessing executed in 1388 ms
# 06:26:35.386 DEBUG b.sim.LoggingParallelEventsManager - Overall processed events: 245390
# 06:26:35.386 INFO  beam.sim.BeamMobsim - Events drained.
# 06:26:35.386 INFO  beam.sim.BeamMobsim - Processing Agentsim Events (End)
# 06:26:38.371 INFO  beam.sim.BeamSim - notifyIterationEnds.start (after GC): 0.2(GB)
# 06:26:38.417 INFO  b.p.j.AgentSimToPhysSimPlanConverter - JDEQSim Start
# 06:26:38.427 INFO  b.p.j.AgentSimToPhysSimPlanConverter - Memory Use Before JDEQSim (after GC): 0.2(GB)
# 06:26:38.512 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 6 completed. 0.2(GB)
# 06:26:38.584 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 7 completed. 0.2(GB)
# 06:26:38.776 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 8 completed. 0.2(GB)
# 06:26:39.467 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 9 completed. 0.2(GB)
# 06:26:39.939 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 10 completed. 0.2(GB)
# 06:26:40.285 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 11 completed. 0.2(GB)
# 06:26:40.565 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 12 completed. 0.2(GB)
# 06:26:40.601 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 13 completed. 0.2(GB)
# 06:26:40.864 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 14 completed. 0.2(GB)
# 06:26:41.102 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 15 completed. 0.2(GB)
# 06:26:41.379 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 16 completed. 0.2(GB)
# 06:26:41.617 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 17 completed. 0.2(GB)
# 06:26:41.646 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 18 completed. 0.2(GB)
# 06:26:41.997 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 19 completed. 0.2(GB)
# 06:26:42.322 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 20 completed. 0.2(GB)
# 06:26:42.349 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 21 completed. 0.2(GB)
# 06:26:42.372 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 22 completed. 0.2(GB)
# 06:26:42.702 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 23 completed. 0.2(GB)
# 06:26:42.966 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 24 completed. 0.2(GB)
# 06:26:42.979 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 25 completed. 0.2(GB)
# 06:26:42.993 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 26 completed. 0.2(GB)
# 06:26:43.224 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 27 completed. 0.2(GB)
# 06:26:43.500 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 28 completed. 0.2(GB)
# 06:26:43.518 INFO  b.p.jdeqsim.JDEQSimMemoryFootprint - Hour 29 completed. 0.2(GB)
# 06:26:43.536 INFO  b.p.j.AgentSimToPhysSimPlanConverter - Memory Use After JDEQSim (after GC): 0.2(GB)
# 06:26:43.542 INFO  b.p.j.AgentSimToPhysSimPlanConverter - JDEQSim End
# 06:26:43.614 INFO  b.utils.TravelTimeCalculatorHelper - GetLinkIdToTravelTimeArray for 5918 links with maxHour = 30 executed in 69 ms
146190, rideHailVehicle-408-2013000895447-049652, rideHailVehicle-201-2016001254527-0152931, rideHailVehicle-1107-2014001093569-084674, rideHailVehicle-1105-2013001154369-154238, rideHailVehicle-10103-2014000584977-074080, rideHailVehicle-10600-2013001200076-055531, rideHailVehicle-1105-2015000712347-2104737, rideHailVehicle-1200-2016001315095-0153830, rideHailVehicle-408-2013000895447-049736, rideHailVehicle-10405-2013000668727-246370, rideHailVehicle-10102-2016001438850-0155549, rideHailVehicle-1105-2014001160693-085864, rideHailVehicle-1105-2013001154369-154198, rideHailVehicle-405-2013001140050-053955, rideHailVehicle-10103-2016001437406-0155486, rideHailVehicle-202-2013000258802-035625, rideHailVehicle-401-2015000542370-0100879, rideHailVehicle-405-2015000260882-096145, rideHailVehicle-407-2012001415668-028459, rideHailVehicle-500-2013001157196-054499, rideHailVehicle-1803-2013000614271-044932, rideHailVehicle-1101-2015001091707-0115875, rideHailVehicle-700-2012000970914-020035
# 06:26:51.032 INFO  beam.sim.BeamSim - notifyIterationEnds.end (after GC): 0.1(GB)
# 06:26:51.032 INFO  beam.sim.BeamSim - Iteration 1 - average number of plans per agent: 4.2771087
# 06:26:51.033 DEBUG beam.sim.metrics.MetricsPrinter - Printer not subscribed.
# 06:26:51.040 INFO  beam.sim.BeamSim - Renaming file - 1.experienced_plans.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.experiencedPlans.xml.gz
# 06:26:51.053 INFO  beam.sim.BeamSim - Renaming file - 1.experienced_plans_scores.txt.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.experiencedPlansScores.txt.gz
# 06:26:51.057 INFO  beam.sim.BeamSim - Renaming file - 1.legHistogram.txt to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.legHistogram.txt
# 06:26:51.057 INFO  beam.sim.BeamSim - Renaming file - 1.legHistogram_all.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.legHistogramAll.png
# 06:26:51.061 INFO  beam.sim.BeamSim - Renaming file - 1.legHistogram_car.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.legHistogramCar.png
# 06:26:51.064 INFO  beam.sim.BeamSim - Renaming file - 1.legHistogram_drive_transit.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.legHistogramDriveTransit.png
# 06:26:51.068 INFO  beam.sim.BeamSim - Renaming file - 1.legHistogram_ride_hail.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.legHistogramRideHail.png
# 06:26:51.071 INFO  beam.sim.BeamSim - Renaming file - 1.legHistogram_walk.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.legHistogramWalk.png
# 06:26:51.075 INFO  beam.sim.BeamSim - Renaming file - 1.legHistogram_walk_transit.png to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/ITERS/it.1/1.legHistogramWalkTransit.png
# 06:26:51.078 INFO  beam.sim.BeamSim - Ending Iteration
# 06:26:52.534 INFO  beam.sim.BeamSim - Generating html page to compare graphs (across all iterations)
# 06:26:52.822 INFO  beam.sim.BeamSim - Actor system shut down
# 06:26:52.827 INFO  beam.sim.BeamSim - Renaming file - output_config.xml to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputConfig.xml
# 06:26:52.831 INFO  beam.sim.BeamSim - Renaming file - output_counts.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputCounts.xml.gz
# 06:26:52.835 INFO  beam.sim.BeamSim - Renaming file - output_events.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputEvents.xml.gz
# 06:26:52.839 INFO  beam.sim.BeamSim - Renaming file - output_facilities.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputFacilities.xml.gz
# 06:26:52.843 INFO  beam.sim.BeamSim - Renaming file - output_households.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputHouseholds.xml.gz
# 06:26:52.847 INFO  beam.sim.BeamSim - Renaming file - output_lanes.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputLanes.xml.gz
# 06:26:52.851 INFO  beam.sim.BeamSim - Renaming file - output_network.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputNetwork.xml.gz
# 06:26:52.856 INFO  beam.sim.BeamSim - Renaming file - output_personAttributes.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputPersonAttributes.xml.gz
# 06:26:52.860 INFO  beam.sim.BeamSim - Renaming file - output_plans.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputPlans.xml.gz
# 06:26:52.864 INFO  beam.sim.BeamSim - Renaming file - output_vehicles.xml.gz to follow camel case notation : /output/sioux_faux/sioux_faux-1k__2019-02-16_06-25-22/outputVehicles.xml.gz
# 06:26:52.869 DEBUG beam.sim.BeamSim - deleting output file: traveldistancestats.txt
# 06:26:52.872 DEBUG beam.sim.BeamSim - deleting output file: traveldistancestats.png
# 06:26:52.875 DEBUG beam.sim.BeamSim - deleting output file: tmp
# 06:26:52.878 DEBUG beam.sim.BeamSim - deleting output file: modestats.txt
# 06:26:52.881 DEBUG beam.sim.BeamSim - deleting output file: modestats.png
# 06:26:53.235 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table feed_info from feed_info.txt
# 06:26:53.239 INFO  com.conveyal.gtfs.GTFSFeed - Feed ID is 'siouxareametro-sd-us'.
# 06:26:53.240 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table agency from agency.txt
# 06:26:53.241 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table calendar from calendar.txt
# 06:26:53.243 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table calendar_dates from calendar_dates.txt
# 06:26:53.245 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table fare_attributes from fare_attributes.txt
# 06:26:53.247 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table fare_rules from fare_rules.txt
# 06:26:53.248 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table routes from routes.txt
# 06:26:53.250 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table shapes from shapes.txt
# 06:26:53.292 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table stops from stops.txt
# 06:26:53.297 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table transfers from transfers.txt
# 06:26:53.298 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table trips from trips.txt
# 06:26:53.304 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table frequencies from frequencies.txt
# 06:26:53.306 INFO  c.conveyal.gtfs.model.Entity$Loader - Loading GTFS table stop_times from stop_times.txt
# 06:26:53.472 INFO  com.conveyal.gtfs.GTFSFeed - 3 errors
# 06:26:53.473 INFO  com.conveyal.gtfs.GTFSFeed - GTFSError: fare_rules line 0: Table is present in zip file, but it has no entries.
# 06:26:53.473 INFO  com.conveyal.gtfs.GTFSFeed - GTFSError: frequencies line 0: Table is present in zip file, but it has no entries.
# 06:26:53.474 INFO  com.conveyal.gtfs.GTFSFeed - GTFSError: transfers line 0: Table is present in zip file, but it has no entries.
# 06:26:53.474 INFO  com.conveyal.gtfs.GTFSFeed - Building stop to stop times index
# 06:26:53.696 INFO  com.conveyal.gtfs.GTFSFeed - Building trips per service index
# 06:26:53.699 INFO  com.conveyal.gtfs.GTFSFeed - Building services per date index

# %% [markdown]
# Submissions run for a certain amount of time. If you interrupt it before the end, you will not get any outputs. You can **check if a submission is finished** with the following method:

# %%
my_executor.check_if_submission_complete('my_submission')
# Out:
# True

# %% [markdown]
# When a simulation run is done, you can import its **results**:

# %%
scores, stats = my_executor.get_submission_scores_and_stats('my_submission')

# %%
scores['Raw Score']
# Out:
# Component Name
# Level of service: costs and benefits                                         1.002339
# Accessibility: Number of secondary locations accessible within 15 minutes    1.020872
# Accessibility: Number of work locations accessible within 15 minutes         0.989149
# Sustainability: Total PM 2.5 Emissions                                       1.011651
# Level of service: average trip expenditure - secondary                       0.880546
# Level of service: average on-demand ride wait times                          0.942077
# Level of service: average bus crowding experienced                           1.049553
# Congestion: total vehicle miles traveled                                     1.014462
# Congestion: average vehicle delay per passenger trip                         0.900014
# Level of service: average trip expenditure - work                            1.010162
# Submission Score                                                                  NaN
# Name: Raw Score, dtype: float64

# %% [markdown]
# The **scores** and **statistics** are stored in pandas DataFrames which contains the information described [here](https://github.com/vgolfier/Uber-Prize-Starter-Kit/blob/master/docs/Understanding_the_outputs_and_the%20scoring_function.md).

# %% [markdown]
# At the end of any run and to avoid any conflicts between submission ids (particularly if you want to reuse names), it is advised to **clean up containers** calling the following method:

# %%
my_executor.stop_all_simulations()
# Out:
# Stopping simulation:
#  Submission_id: my_submission
# 	 Scenario name: sioux_faux
# 	 # iters: 1
# 	 sample size: 1k
# Done.

# %% [markdown]
# ## The `input_sampler` module:

# %% [markdown]
# Randomly sampled data may be used to either initialize the re-planning algorithm or otherwise test the simulation. The `input_sampler` has been provided towards this end. This subsection provides an example of how synthetic random input files may be generated for each of the available input policies to the simulation.

# %%
from input_sampler import *
# Specify the common string for the scenario name 
# (currently only "siouxfalls", which refers to the Sioux Falls scenario).
agency = 'sioux_faux_bus_lines'

# Set the paths appropriately
DIR = Path(__name__).absolute().parent.parent
sys.path.append(str(DIR))
DATA_DIR = DIR / 'reference-data/'

agency_dict = scenario_agencies(DATA_DIR,SCENARIO_NAME)
    # Create a lazy cache of GTFS data for the agency:
sf_gtfs_manager = AgencyGtfsDataManager(agency_dict[agency])

# Sample each input five (5) times (naming of functions is indicative of type of input sampled).
freq_df = sample_frequency_adjustment_input(5, sf_gtfs_manager)
mode_incentive_df = sample_mode_incentives_input(5)
vehicle_fleet_mix_df = sample_vehicle_fleet_mix_input(5, sf_gtfs_manager)

# Generated inputs may now be saved in, say, /submission-inputs or some other directory. 
# Remember the location of this directory when executing new simulations.

# %%
vehicle_fleet_mix_df
# Out:
#    agencyId  routeId vehicleTypeId
# 0       217     1347  BUS-SMALL-HD
# 1       217     1340   BUS-STD-ART
# 2       217     1348  BUS-SMALL-HD
# 3       217     1342   BUS-STD-ART
# 4       217     1350   BUS-DEFAULT

# %%
mode_incentive_df
# Out:
#             mode       age           income amount
# 0  ondemand_ride  (92:118]  (168000:294000)   18.7
# 1  ondemand_ride   [29:32)  [104000:199000)   20.0
# 2   walk_transit   [34:91]   [98000:205000)    1.4
# 3   walk_transit   (24:88)   [38000:286000)    6.5
# 4  drive_transit    (6:90]    (37000:77000)   19.4

# %%
freq_df
# Out:
#                trip_id  start_time  end_time  headway_secs  exact_times
# 0   t_75331_b_219_tn_1       29400     41880          4320            0
# 1  t_75326_b_219_tn_10       72540     83580          3540            0
# 2   t_72464_b_219_tn_8       44220     72120          5100            0
# 3   t_72463_b_219_tn_5       24840     80160          2820            0
# 4   t_75350_b_219_tn_6       13500     67320          3780            0
